# %% [markdown]
# # Electrical Load Forcasting using Machine Learning (Roll-160,173)

# %%
from IPython.display import Image
Image(filename="C:\\Users\\hp\\Documents\\Presentation1.jpg",width=900,height=100)

# %% [markdown]
# # Importing Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

#libraries for prediction
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Importing Dataset & Display

# %%
df=pd.read_excel('E:\\RUET Study EEE\\3rd Year\\3-2\\6.Circuit Simulation Lab (EEE 3200)\\Project\\Load Forcasting\\Load Demand Data.xlsx')
df
# Out:
#     Day  Load Demand(MW)
# 0     1            16900
# 1     2            18100
# 2     3            17500
# 3     4            16800
# 4     5            16300
# 5     6            17200
# 6     7            17600
# 7     8            17200
# 8     9            16700
# 9    10            16500
# 10   11            16300
# 11   12            15900
# 12   13            15700
# 13   14            15400
# 14   15            15900
# 15   16            15300
# 16   17            15100
# 17   18            15800
# 18   19            16000
# 19   20            16400
# 20   21            16900
# 21   22            17100
# 22   23            17300
# 23   24            17800
# 24   25            18100
# 25   26            18400
# 26   27            17900
# 27   28            17400
# 28   29            17100
# 29   30            16900

# %% [markdown]
# # Splitting for Train & Test Purpose

# %%
x = df.iloc[:, :-1].values #all rows and all columns up to the last one
y=df.iloc[:,1].values

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %% [markdown]
# # Train Model

# %%
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Prediction

# %%
y_pred=regressor.predict(x_test)

# %% [markdown]
# # Final Output

# %%
# Get the predicted load demand for the 31st day
predicted_load_31st_day = regressor.predict([[31]])

# Add the predicted load demand to the existing dataframe
new_row = pd.DataFrame([[31, predicted_load_31st_day]], columns=['Day', 'Load Demand (MW)'])
df = df.append(new_row, ignore_index=True)

# Print the updated dataframe
df
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_17968\571996287.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
#     Day  Load Demand(MW)      Load Demand (MW)
# 0     1          16900.0                   NaN
# 1     2          18100.0                   NaN
# 2     3          17500.0                   NaN
# 3     4          16800.0                   NaN
# 4     5          16300.0                   NaN
# 5     6          17200.0                   NaN
# 6     7          17600.0                   NaN
# 7     8          17200.0                   NaN
# 8     9          16700.0                   NaN
# 9    10          16500.0                   NaN
# 10   11          16300.0                   NaN
# 11   12          15900.0                   NaN
# 12   13          15700.0                   NaN
# 13   14          15400.0                   NaN
# ...
